# %% [markdown]
# <a href="https://colab.research.google.com/github/prakashgoud421/FragmentTransaction/blob/fragment/LangChain_Overview.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q llama-cpp-python langchain gradio sentence-transformers chromadb PyPDF2
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 MB 6.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 4.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.9/46.9 MB 16.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.2/322.2 kB 18.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 57.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 59.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 kB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 14.6 MB/s eta 0:00:00
# ...

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
import google.generativeai as genai
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_community.document_loaders import PyPDFLoader
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS
from langchain.chains import RetrievalQA
from langchain.text_splitter import RecursiveCharacterTextSplitter
import os
from google.colab import files
from google.colab import userdata
from llama_cpp import Llama
from langchain.llms import LlamaCpp

# %%
# Replace with your actual API key
genai.configure(api_key=userdata.get('GOOGLE_API_KEY'))

# %%
uploaded = files.upload()

pdf_path = list(uploaded.keys())[0]
print(f"Loaded PDF: {pdf_path}")
# Out:
#      <input type="file" id="files-c71c8138-47f7-443e-a09b-beb125e790aa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c71c8138-47f7-443e-a09b-beb125e790aa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
loader = PyPDFLoader(pdf_path)
documents = loader.load()

text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
docs = text_splitter.split_documents(documents)

# %%
embedding = HuggingFaceEmbeddings()
db = FAISS.from_documents(docs, embedding)
retriever = db.as_retriever()
# Out:
# <ipython-input-45-cad00a612644>:1: LangChainDeprecationWarning: Default values for HuggingFaceEmbeddings.model_name were deprecated in LangChain 0.2.16 and will be removed in 0.4.0. Explicitly pass a model_name to the HuggingFaceEmbeddings constructor instead.
#   embedding = HuggingFaceEmbeddings()

# %%
llm_path = r"C:\Users\Ediga8.Goud\Downloads\ggml-model-q4_0.gguf"

llm_cpp = LlamaCpp(
    model_path=llm_path,
    n_ctx=2048,
    n_threads=4,
    temperature=0.7,
    top_p=0.9
)

qa_chain = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=retriever,
    return_source_documents=True
)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# <ipython-input-46-ae36d0a67eb7> in <cell line: 0>()
#       1 llm_path = r"C:\Users\Ediga8.Goud\Downloads\ggml-model-q4_0.gguf"
#       2
# ----> 3 llm_cpp = LlamaCpp(
#       4     model_path=llm_path,
#       5     n_ctx=2048,
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/load/serializable.py in __init__(self, *args, **kwargs)
#     128     def __init__(self, *args: Any, **kwargs: Any) -> None:
#     129         """"""  # noqa: D419
# --> 130         super().__init__(*args, **kwargs)
#     131
#     132     @classmethod
#
# /usr/local/lib/python3.11/dist-packages/pydantic/main.py in __init__(self, **data)
#     241         # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     242         __tracebackhide__ = True
# ...

# %%
while True:
    query = input("Ask a question (type 'exit' to quit): ")
    if query.lower() == "exit":
        break
    result = qa_chain(query)
    print("\nAnswer:", result["result"])
# Out:
# Ask a question (type 'exit' to quit): lang
# <ipython-input-22-74c7cdf75c7f>:5: LangChainDeprecationWarning: The method `Chain.__call__` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   result = qa_chain(query)
# WARNING:langchain_google_genai.chat_models:Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised NotFound: 404 models/gemini-pro is not found for API version v1beta, or is not supported for generateContent. Call ListModels to see the list of available models and their supported methods..
# ---------------------------------------------------------------------------
# NotFound                                  Traceback (most recent call last)
# <ipython-input-22-74c7cdf75c7f> in <cell line: 0>()
#       3     if query.lower() == "exit":
#       4         break
# ----> 5     result = qa_chain(query)
#       6     print("\nAnswer:", result["result"])
#
# ...

# %%
import os
from google.colab import files

# Upload the GGUF model from your Windows machine to Colab
uploaded = files.upload()

print(os.path.exists(r"C:\Users\Ediga8.Goud\Downloads\ggml-model-q4_0.gguf"))
# Out:
#      <input type="file" id="files-838bbdc0-c2e9-4872-a360-d4553c9ac7a5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-838bbdc0-c2e9-4872-a360-d4553c9ac7a5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
